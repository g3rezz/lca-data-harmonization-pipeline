# %% [markdown]
# # Covert ILCD HTML files to CSV

# %%
import os
from bs4 import BeautifulSoup
import pandas as pd

# Specify the directory containing the HTML files
html_directory = '../data/html'
output_directory = '../data/csv'

# Ensure the output directory exists
os.makedirs(output_directory, exist_ok=True)

# Mapping of inconsistent headers to standardized headers
header_mapping = {
    'Field name': 'Field Name (en)',
    'Field name (de)': 'Field Name (de)',
    'Field name (en)': 'Field Name (en)',
    'Element/Attribute name': 'Element/Attribute Name',
    'Element/attribute name': 'Element/Attribute Name',
    'Data type': 'Datatype',
    'Definition': 'Definition (en)',
}

# Loop through all HTML files in the directory
for file_name in os.listdir(html_directory):
    if file_name.endswith('.html'):
        html_file_path = os.path.join(html_directory, file_name)
        csv_file_name = os.path.splitext(file_name)[0] + '.csv'
        csv_output_path = os.path.join(output_directory, csv_file_name)

        print(f"Processing: {file_name}")

        # Load the HTML content
        with open(html_file_path, 'r', encoding='utf-8') as file:
            html_content = file.read()

        # Parse the HTML content with BeautifulSoup
        soup = BeautifulSoup(html_content, 'html.parser')

        # Find the table by its ID (adjust if necessary for your files)
        table = soup.find('table', {'id': 'tableID'})
        if not table:
            print(f"No table with id 'tableID' found in {file_name}. Skipping.")
            continue

        # Extract headers and rows from the table
        headers = [header_mapping.get(th.get_text(strip=True), th.get_text(strip=True)) for th in table.find_all('th')]
        rows = [
            [' '.join(td.get_text(strip=True).split()) for td in tr.find_all('td')]
            for tr in table.find_all('tr')
        ]

        # Ensure consistent column length
        max_columns = max(len(row) for row in rows)
        adjusted_rows = [row + [''] * (max_columns - len(row)) for row in rows]
        adjusted_headers = headers + [''] * (max_columns - len(headers))

        # Create a DataFrame
        df = pd.DataFrame(adjusted_rows, columns=adjusted_headers)

        # Clean empty cells by replacing whitespace-only entries with NaN
        df.replace(r"^\s*$", pd.NA, regex=True, inplace=True)

        # Print summary before dropping empty columns
        print("Before dropping empty columns:")
        print(df.info())

        # Drop columns with all empty values
        df = df.dropna(axis=1, how='all')

        # Drop rows with all empty values
        df = df.dropna(axis=0, how="all")

        # Print summary after dropping empty columns
        print("After dropping empty columns:")
        print(df.info())

        # Save the cleaned DataFrame as CSV
        df.to_csv(csv_output_path, index=False, encoding='utf-8')

        print(f"Saved: {csv_output_path}")

print("Processing complete.")
# Out:
# Processing: EPD_DataSet.html
# Before dropping empty columns:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Field Name (de)                       161 non-null    object
#  1   Field Name (en)                       159 non-null    object
#  2   Element/Attribute Name                160 non-null    object
#  3   Requ.                                 160 non-null    object
#  4   Occ.                                  120 non-null    object
#  5   Datatype                              103 non-null    object
#  6   Definition (de)                       137 non-null    object
#  7   Definition (en)                       125 non-null    object
#  8   Original ILCD Format Definition (en)  102 non-null    object
#  9   eDoc ID                               102 non-null    object
#  10                                        19 non-null     object
#  11                                        1 non-null      object
# dtypes: object(12)
# memory usage: 15.2+ KB
# None
# After dropping empty columns:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Field Name (de)                       161 non-null    object
#  1   Field Name (en)                       159 non-null    object
#  2   Element/Attribute Name                160 non-null    object
#  3   Requ.                                 160 non-null    object
#  4   Occ.                                  120 non-null    object
#  5   Datatype                              103 non-null    object
#  6   Definition (de)                       137 non-null    object
#  7   Definition (en)                       125 non-null    object
#  8   Original ILCD Format Definition (en)  102 non-null    object
#  9   eDoc ID                               102 non-null    object
#  10                                        19 non-null     object
#  11                                        1 non-null      object
# dtypes: object(12)
# memory usage: 15.2+ KB
# None
# Saved: ../data/csv\EPD_DataSet.csv
# Processing: EPD_FlowDataSet.html
# Before dropping empty columns:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 12 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Field Name (de)                       5 non-null      object
#  1   Field Name (en)                       84 non-null     object
#  2   Element/Attribute Name                86 non-null     object
#  3   Requ.                                 86 non-null     object
#  4   Occ.                                  75 non-null     object
#  5   Datatype                              46 non-null     object
#  6   Definition (de)                       5 non-null      object
#  7   Definition (en)                       5 non-null      object
#  8   Original ILCD Format Definition (en)  78 non-null     object
#  9   eDoc ID                               79 non-null     object
#  10                                        2 non-null      object
#  11                                        0 non-null      object
# dtypes: object(12)
# memory usage: 8.3+ KB
# None
# After dropping empty columns:
# <class 'pandas.core.frame.DataFrame'>
# Index: 86 entries, 1 to 86
# Data columns (total 11 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Field Name (de)                       5 non-null      object
#  1   Field Name (en)                       84 non-null     object
#  2   Element/Attribute Name                86 non-null     object
#  3   Requ.                                 86 non-null     object
#  4   Occ.                                  75 non-null     object
#  5   Datatype                              46 non-null     object
#  6   Definition (de)                       5 non-null      object
#  7   Definition (en)                       5 non-null      object
#  8   Original ILCD Format Definition (en)  78 non-null     object
#  9   eDoc ID                               79 non-null     object
#  10                                        2 non-null      object
# dtypes: object(11)
# memory usage: 8.1+ KB
# None
# Saved: ../data/csv\EPD_FlowDataSet.csv
# Processing: ILCD_Common_DataTypes.html
# Before dropping empty columns:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Data Type    34 non-null     object
#  1   Base Type    29 non-null     object
#  2   Description  30 non-null     object
# dtypes: object(3)
# memory usage: 972.0+ bytes
# None
# After dropping empty columns:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, 1 to 34
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Data Type    34 non-null     object
#  1   Base Type    29 non-null     object
#  2   Description  30 non-null     object
# dtypes: object(3)
# memory usage: 1.1+ KB
# None
# Saved: ../data/csv\ILCD_Common_DataTypes.csv
# Processing: ILCD_Common_EnumerationValues.html
# Before dropping empty columns:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 411 entries, 0 to 410
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   List name        410 non-null    object
#  1   Value            363 non-null    object
#  2   Definition (en)  27 non-null     object
# dtypes: object(3)
# memory usage: 9.8+ KB
# None
# After dropping empty columns:
# <class 'pandas.core.frame.DataFrame'>
# Index: 410 entries, 1 to 410
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   List name        410 non-null    object
#  1   Value            363 non-null    object
#  2   Definition (en)  27 non-null     object
# dtypes: object(3)
# memory usage: 12.8+ KB
# None
# Saved: ../data/csv\ILCD_Common_EnumerationValues.csv
# Processing: ILCD_ContactDataSet.html
# Before dropping empty columns:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Field Name (en)         39 non-null     object
#  1   Element/Attribute Name  39 non-null     object
#  2   Requ.                   39 non-null     object
#  3   Occ.                    34 non-null     object
#  4   Datatype                23 non-null     object
#  5   Definition (en)         36 non-null     object
#  6   eDoc ID                 39 non-null     object
# dtypes: object(7)
# memory usage: 2.3+ KB
# None
# After dropping empty columns:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39 entries, 1 to 39
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Field Name (en)         39 non-null     object
#  1   Element/Attribute Name  39 non-null     object
#  2   Requ.                   39 non-null     object
#  3   Occ.                    34 non-null     object
#  4   Datatype                23 non-null     object
#  5   Definition (en)         36 non-null     object
#  6   eDoc ID                 39 non-null     object
# dtypes: object(7)
# memory usage: 2.4+ KB
# None
# Saved: ../data/csv\ILCD_ContactDataSet.csv
# Processing: ILCD_FlowPropertyDataSet.html
# Before dropping empty columns:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Field Name (en)         43 non-null     object
#  1   Element/Attribute Name  44 non-null     object
#  2   Requ.                   44 non-null     object
#  3   Occ.                    39 non-null     object
#  4   Datatype                19 non-null     object
#  5   Definition (en)         39 non-null     object
#  6   eDoc ID                 43 non-null     object
# dtypes: object(7)
# memory usage: 2.6+ KB
# None
# After dropping empty columns:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44 entries, 1 to 44
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Field Name (en)         43 non-null     object
#  1   Element/Attribute Name  44 non-null     object
#  2   Requ.                   44 non-null     object
#  3   Occ.                    39 non-null     object
#  4   Datatype                19 non-null     object
#  5   Definition (en)         39 non-null     object
#  6   eDoc ID                 43 non-null     object
# dtypes: object(7)
# memory usage: 2.8+ KB
# None
# Saved: ../data/csv\ILCD_FlowPropertyDataSet.csv
# Processing: ILCD_LCIAMethodDataSet.html
# Before dropping empty columns:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Field Name (en)         143 non-null    object
#  1   Element/Attribute Name  148 non-null    object
#  2   Requ.                   147 non-null    object
#  3   Occ.                    135 non-null    object
#  4   Datatype                93 non-null     object
#  5   Definition (en)         133 non-null    object
#  6   eDoc ID                 143 non-null    object
# dtypes: object(7)
# memory usage: 8.3+ KB
# None
# After dropping empty columns:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148 entries, 1 to 148
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Field Name (en)         143 non-null    object
#  1   Element/Attribute Name  148 non-null    object
#  2   Requ.                   147 non-null    object
#  3   Occ.                    135 non-null    object
#  4   Datatype                93 non-null     object
#  5   Definition (en)         133 non-null    object
#  6   eDoc ID                 143 non-null    object
# dtypes: object(7)
# memory usage: 9.2+ KB
# None
# Saved: ../data/csv\ILCD_LCIAMethodDataSet.csv
# Processing: ILCD_SourceDataSet.html
# Before dropping empty columns:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Field Name (en)         35 non-null     object
#  1   Element/Attribute Name  36 non-null     object
#  2   Requ.                   36 non-null     object
#  3   Occ.                    30 non-null     object
#  4   Datatype                19 non-null     object
#  5   Definition (en)         33 non-null     object
#  6   eDoc ID                 35 non-null     object
# dtypes: object(7)
# memory usage: 2.2+ KB
# None
# After dropping empty columns:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36 entries, 1 to 36
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Field Name (en)         35 non-null     object
#  1   Element/Attribute Name  36 non-null     object
#  2   Requ.                   36 non-null     object
#  3   Occ.                    30 non-null     object
#  4   Datatype                19 non-null     object
#  5   Definition (en)         33 non-null     object
#  6   eDoc ID                 35 non-null     object
# dtypes: object(7)
# memory usage: 2.2+ KB
# None
# Saved: ../data/csv\ILCD_SourceDataSet.csv
# Processing: ILCD_UnitGroupDataSet.html
# Before dropping empty columns:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Field Name (en)         48 non-null     object
#  1   Element/Attribute Name  49 non-null     object
#  2   Requ.                   49 non-null     object
#  3   Occ.                    43 non-null     object
#  4   Datatype                21 non-null     object
#  5   Definition (en)         44 non-null     object
#  6   eDoc ID                 48 non-null     object
# dtypes: object(7)
# memory usage: 2.9+ KB
# None
# After dropping empty columns:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49 entries, 1 to 49
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Field Name (en)         48 non-null     object
#  1   Element/Attribute Name  49 non-null     object
#  2   Requ.                   49 non-null     object
#  3   Occ.                    43 non-null     object
#  4   Datatype                21 non-null     object
#  5   Definition (en)         44 non-null     object
#  6   eDoc ID                 48 non-null     object
# dtypes: object(7)
# memory usage: 3.1+ KB
# None
# Saved: ../data/csv\ILCD_UnitGroupDataSet.csv
# Processing complete.

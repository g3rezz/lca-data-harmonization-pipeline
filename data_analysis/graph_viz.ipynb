# %%
# -------------------------------------------------------------
# Export a large TTL (≈125 k triples) to colored GraphML for Gephi
# -------------------------------------------------------------
# pip install rdflib networkx matplotlib             # first run only

import rdflib                             # RDF parser
import networkx as nx                     # Graph container + GraphML writer
from matplotlib import cm                 # Colormap to pick distinct colors
from matplotlib.colors import to_hex
import rdflib.namespace as rns

# --- 1. Load TTL -----------------------------------------------------------
TTL_FILE = "../linkml/data/rdf/epd_rdf_instance_datastore_canonical_skos_din_bki_shacl.ttl"

rdf = rdflib.Graph()
rdf.parse(TTL_FILE, format="turtle")

# --- 2. Build a directed NetworkX graph ------------------------------------
G = nx.DiGraph()

for s, p, o in rdf:
    # Parse URIs as plain strings; literals become str(literal)
    su, ob = str(s), str(o)

    G.add_node(su)
    G.add_node(ob)
    # predicate label kept if you want to filter later
    G.add_edge(su, ob, predicate=str(p))

# --- 3. Assign deterministic colors by namespace prefix --------------------
# Helper: get prefix (falls back to “misc”)
ns_mgr = rdf.namespace_manager
def qprefix(uri: str) -> str:
    try:
        return ns_mgr.compute_qname(rdflib.URIRef(uri))[0]
    except Exception:
        return "misc"

# List unique prefixes
prefixes = sorted({qprefix(n) for n in G.nodes})
# Map each prefix to a distinct color from matplotlib's tab20 colormap
cmap = cm.get_cmap("tab20", len(prefixes))
prefix2color = {pref: to_hex(cmap(i)) for i, pref in enumerate(prefixes)}

# Write the color attribute (hex) to each node
for n in G.nodes:
    G.nodes[n]["color"] = prefix2color[qprefix(n)]

# --- 4. Export to GraphML ---------------------------------------------------
OUT_FILE = "ttl_graph_ready_for_gephi.graphml"
nx.write_graphml(G, OUT_FILE)
print(f"✔ GraphML written to {OUT_FILE} — import in Gephi and run a layout.")
# Out:
# source data set does not look like a valid URI, trying to serialize this will break.
# compressive strength does not look like a valid URI, trying to serialize this will break.
# unit group data set does not look like a valid URI, trying to serialize this will break.
# Building products made of concrete and concrete elements - Firmengruppe Max Bögl - Concrete C30/37 fly ash does not look like a valid URI, trying to serialize this will break.
# Eutrophication potential - terrestrial (EP-terrestrial) does not look like a valid URI, trying to serialize this will break.
# Product flow does not look like a valid URI, trying to serialize this will break.
# Beton C20/25 X0 C1 22 L EcoPact, Rezept Nummer DU3312-AHZS, Transportbetonwerk Büttelborn, Germany does not look like a valid URI, trying to serialize this will break.
# Beton C20/25 XC1 XC2 F3 16 M ECOPact, Rezept Nummer DI3234-BHFS Version 1, Transportbetonwerk Balve, Germany does not look like a valid URI, trying to serialize this will break.
# Global Warming Potential (GWP-GHG) does not look like a valid URI, trying to serialize this will break.
# Materials for energy recovery (MER) does not look like a valid URI, trying to serialize this will break.
# LCIA method data set does not look like a valid URI, trying to serialize this will break.
# contact data set does not look like a valid URI, trying to serialize this will break.
# Other flow does not look like a valid URI, trying to serialize this will break.
# ILCD format does not look like a valid URI, trying to serialize this will break.
# Fully compliant does not look like a valid URI, trying to serialize this will break.
# Utarmingspotensial for vannressurser (WDP) does not look like a valid URI, trying to serialize this will break.
# Eksportert termisk energi (ETE) does not look like a valid URI, trying to serialize this will break.
# Ioniserende stråling, helseeffekt (IRP) does not look like a valid URI, trying to serialize this will break.
# Globalt oppvarmingspotensial - fossile brensler (GWP-fossil) does not look like a valid URI, trying to serialize this will break.
# EN 15804+A2 does not look like a valid URI, trying to serialize this will break.
# flow data set does not look like a valid URI, trying to serialize this will break.
# Die dosierten Gesteinskörnungen werden zunächst trocken mit Zement als Bindemittel und weiteren Zusatzstoffen vorgemischt. Danach wird die Mischung mit Wasser zu einem plastisch verformbaren Frischbeton gemischt.
#
# Dieser wird ohne Lagerung mit Betonfahrmischern auf die Baustelle transportiert und dort in die vorbereitete Schalung (i. d. R. mit Bewehrung) eingebracht und verdichtet.
#
# Zur Sicherung der Betonqualität ist ein Qualitätssicherungssystem im Werk Unna installiert, das sich an den Anforderungen an die werkseigene Produktionskontrolle in BS 8500 und DIN 1045-2 orientiert.  does not look like a valid URI, trying to serialize this will break.
# ,  does not look like a valid URI, trying to serialize this will break.
# Größen / Umweltliche Größen / EPD EN 15804 / LCI Indikatoren does not look like a valid URI, trying to serialize this will break.
# Potensial for nedbryting av stratosfærisk ozon (ODP) does not look like a valid URI, trying to serialize this will break.
# Exported electrical energy (EEE) does not look like a valid URI, trying to serialize this will break.
# Eutrophication potential - marine (EP-marine) does not look like a valid URI, trying to serialize this will break.
# EPD Data Format Extensions v1.2 does not look like a valid URI, trying to serialize this will break.
# Global Warming Potential - biogenic (GWP-biogenic) does not look like a valid URI, trying to serialize this will break.
# LCA.no AS does not look like a valid URI, trying to serialize this will break.
# Non hazardous waste dispose (NHWD) does not look like a valid URI, trying to serialize this will break.
# Global Warming Potential - total (GWP-total) does not look like a valid URI, trying to serialize this will break.
# Abiotic depletion potential - fossil resources (ADPF) does not look like a valid URI, trying to serialize this will break.
# Photochemical Ozone Creation Potential (POCP) does not look like a valid URI, trying to serialize this will break.
# specific dataset does not look like a valid URI, trying to serialize this will break.
# CLS Rck30 S4 XC2 D25 CEM III 42,5 N-LH/SR CAM does not look like a valid URI, trying to serialize this will break.
# Use of renewable secondary fuels (RSF) does not look like a valid URI, trying to serialize this will break.
# Institut Bauen und Umwelt e. V. does not look like a valid URI, trying to serialize this will break.
# kilograms per cubic metre does not look like a valid URI, trying to serialize this will break.
# kg CO2 eq. does not look like a valid URI, trying to serialize this will break.
# kBq U235 eq. does not look like a valid URI, trying to serialize this will break.
# Potential Soil quality index (SQP) does not look like a valid URI, trying to serialize this will break.
# PCR - Betonbauteile aus Ort- oder Lieferbeton/ Concrete components made of in-situ or ready-mixed concrete.pdf does not look like a valid URI, trying to serialize this will break.
# Use of renewable primary energy (PERE) does not look like a valid URI, trying to serialize this will break.
# Bruk av fornybart sekundære brensel (RSF) does not look like a valid URI, trying to serialize this will break.
# gross density does not look like a valid URI, trying to serialize this will break.
# Potenzielle Toxizitätsvergleichseinheit für den Menschen - nicht kanzerogene Wirkung (HTP-nc) does not look like a valid URI, trying to serialize this will break.
# Beton C20/25 X0 C1 16 M EcoPact, Rezept Nummer DU3214-AHZK, Transportbetonwerk Saarwellingen, Germany does not look like a valid URI, trying to serialize this will break.
# Radioactive waste disposed (RWD) does not look like a valid URI, trying to serialize this will break.
# Quantities / Environmental quantities / EPD EN 15804 / LCI indicators does not look like a valid URI, trying to serialize this will break.
# Holcim (Deutschland) GmbH does not look like a valid URI, trying to serialize this will break.
# Material for Energy Recovery (MER) does not look like a valid URI, trying to serialize this will break.
# EPD Bauprodukte aus Beton und Betonelemente - Firmengruppe Max Bögl - Beton C30/37 does not look like a valid URI, trying to serialize this will break.
# Påvirkninger knyttet til arealbruksendringer / jordkvalitet (SQP) does not look like a valid URI, trying to serialize this will break.
# Die dosierten Gesteinskörnungen werden zunächst trocken mit Zement als Bindemittel und weiteren Zusatzstoffen vorgemischt. Danach wird die Mischung mit Wasser zu einem plastisch verformbaren Frischbeton gemischt.
#
# Dieser wird ohne Lagerung mit Betonfahrmischern auf die Baustelle transportiert und dort in die vorbereitete Schalung (i. d. R. mit Bewehrung) eingebracht und verdichtet.
#
# Zur Sicherung der Betonqualität ist ein Qualitätssicherungssystem im Werk Mülheim installiert, das sich an den Anforderungen an die werkseigene Produktionskontrolle in BS 8500 und DIN 1045-2 orientiert.  does not look like a valid URI, trying to serialize this will break.
# Carbon content (biogenic) - packaging does not look like a valid URI, trying to serialize this will break.
# EPD Norway does not look like a valid URI, trying to serialize this will break.
# ILCD Format 1.1 does not look like a valid URI, trying to serialize this will break.
# Water (user) deprivation potential (WDP) does not look like a valid URI, trying to serialize this will break.
# process data set does not look like a valid URI, trying to serialize this will break.
# Hazardous waste disposed (HWD) does not look like a valid URI, trying to serialize this will break.
# Abiotic depletion potential - non-fossil resources (ADPE) does not look like a valid URI, trying to serialize this will break.
# Potential Comparative Toxic Unit for humans - cancer effects (HTP-c) does not look like a valid URI, trying to serialize this will break.
# kg N eq. does not look like a valid URI, trying to serialize this will break.
# Exported thermal energy (EET) does not look like a valid URI, trying to serialize this will break.
# Use of net fresh water (FW) does not look like a valid URI, trying to serialize this will break.
# kg CFC 11-Äquiv. does not look like a valid URI, trying to serialize this will break.
# Mineral building products does not look like a valid URI, trying to serialize this will break.
# Gründung, Unterbau für Bodenplatten, mit extrudierten Polystyrolplatten, 100 mm Perimeterdämmung, Sauberkeitsschicht, mit Trennlage does not look like a valid URI, trying to serialize this will break.
# Climate Earth, Inc. does not look like a valid URI, trying to serialize this will break.
# Human toxicity, non-cancer effects (HTP-nc) does not look like a valid URI, trying to serialize this will break.
# kg P eqv. does not look like a valid URI, trying to serialize this will break.
# Potential Human exposure efficiency relative to U235 (IRP) does not look like a valid URI, trying to serialize this will break.
# Total use of non renewable primary energy resource (PENRT) does not look like a valid URI, trying to serialize this will break.
# kg NMVOC eqv. does not look like a valid URI, trying to serialize this will break.
# Independent external review does not look like a valid URI, trying to serialize this will break.
# Potential Comparative Toxic Unit for humans - non-cancer effects (HTP-nc) does not look like a valid URI, trying to serialize this will break.
# Reference flow(s) does not look like a valid URI, trying to serialize this will break.
# Bauprodukte aus Beton und Betonelemente - Firmengruppe Max Bögl - Beton C30/37 latent-hydraulischer Zusatzstoff does not look like a valid URI, trying to serialize this will break.
# kg/m^3 does not look like a valid URI, trying to serialize this will break.
# Normal- Leicht- und Porenbeton does not look like a valid URI, trying to serialize this will break.
# Without unit does not look like a valid URI, trying to serialize this will break.
# mol N eq. does not look like a valid URI, trying to serialize this will break.
# Netto bruk av ferskvann (W) does not look like a valid URI, trying to serialize this will break.
# The Emidat EPD Tool v1.0.0 was used for LCA modeling and calculation. Background data was used from ecoinvent database
# v3.10.
#
# Elementary flows (energy and fuels, ancillary materials and waste) data was collected on production-process-level. Using the
# total output of the production process in 2022, elementary flows are assigned to 1 declared unit based on volume.
#
# Environmental impacts of the following processes are considered to be negligible: Production and use of formwork and
# falsework for the installation of concrete, Materials used for the curing of concrete (e.g. plastics, aluminum).
#  does not look like a valid URI, trying to serialize this will break.
# The Federal Institute for Research on Building, Urban Affairs and Spatial Development (BBSR) within the Federal Office for Building and Regional Planning (BBR) does not look like a valid URI, trying to serialize this will break.
# Globalt oppvarmingspotensial beregnet etter prinsippet om umiddelbar oksidasjon (GWP-IOBC) does not look like a valid URI, trying to serialize this will break.
# ecoinvent 3.5 database does not look like a valid URI, trying to serialize this will break.
# ISO 14025 does not look like a valid URI, trying to serialize this will break.
# ANLÆGSBETON (C35/45 Slump Concrete in Aggressive Environmental Exposure Class) does not look like a valid URI, trying to serialize this will break.
# Globales Erwärmungspotenzial - biogen (GWP-biogenic) does not look like a valid URI, trying to serialize this will break.
# mol H+ eqv. does not look like a valid URI, trying to serialize this will break.
# Use of renewable primary energy resources used as raw materials (PERM) does not look like a valid URI, trying to serialize this will break.
# , gm.nardelli@financo.it does not look like a valid URI, trying to serialize this will break.
# ecoinvent database (general) does not look like a valid URI, trying to serialize this will break.
# Avhendet ikke-farlig avfall (NHW) does not look like a valid URI, trying to serialize this will break.
# Use of non renewable primary energy as energy carrier (PENRE) does not look like a valid URI, trying to serialize this will break.
# Potential incidence of disease due to PM emissions (PM) does not look like a valid URI, trying to serialize this will break.
# kg/m^2 does not look like a valid URI, trying to serialize this will break.
# Free of charge for all users and uses does not look like a valid URI, trying to serialize this will break.
# EPD-Datenformaterweiterungen v1.2 does not look like a valid URI, trying to serialize this will break.
# disease incidence does not look like a valid URI, trying to serialize this will break.
# Total use of renewable primary energy (PERT) does not look like a valid URI, trying to serialize this will break.
# Costituents, production and use in Italy.  does not look like a valid URI, trying to serialize this will break.
# Potenzielle Toxizitätsvergleichseinheit für den Menschen - kanzerogene Wirkung (HTP-c) does not look like a valid URI, trying to serialize this will break.
# Komponenter for gjenbruk (CR) does not look like a valid URI, trying to serialize this will break.
# Global Warming Potential - land use and land use change (GWP-luluc) does not look like a valid URI, trying to serialize this will break.
# Global warming potential except emissions and uptake of biogenic carbon (GWP-IOBC/GHG) does not look like a valid URI, trying to serialize this will break.
# Non harzardous waste disposed (NHWD) does not look like a valid URI, trying to serialize this will break.
# mol H+ eq. does not look like a valid URI, trying to serialize this will break.
# Construction products, Infrastructure & buildings does not look like a valid URI, trying to serialize this will break.
# Human toxicity, cancer effect (HTP-c) does not look like a valid URI, trying to serialize this will break.
# Avhendet farlig avfall (HW) does not look like a valid URI, trying to serialize this will break.
# Use of non renewable primary energy resources used as raw materials (PENRM) does not look like a valid URI, trying to serialize this will break.
# kg CO2 eqv. does not look like a valid URI, trying to serialize this will break.
# Potential Comparative Toxic Unit for ecosystems (ETP-fw) does not look like a valid URI, trying to serialize this will break.
# Betonbauteile aus Ort- oder Lieferbeton does not look like a valid URI, trying to serialize this will break.
# kg CO_(2) eqv. does not look like a valid URI, trying to serialize this will break.
# Bruk av sekundære materialer (SM) does not look like a valid URI, trying to serialize this will break.
# Bruk av ikke fornybart sekundære brensel (NRSF) does not look like a valid URI, trying to serialize this will break.
# Mortar and Concrete does not look like a valid URI, trying to serialize this will break.
# "2023-11-14" - "2028-11-14" does not look like a valid URI, trying to serialize this will break.
# NPCR 020:2018 Part B for Concrete and concrete elements does not look like a valid URI, trying to serialize this will break.
# Use of secondary material (SM) does not look like a valid URI, trying to serialize this will break.
# Matthias Schulz does not look like a valid URI, trying to serialize this will break.
# Die angewendete LCI Methode ist in Übereinstimmung mit ISO 14040 und 14044. Die Dokumentation enthält alle relevanten Informationen im Hinblick auf die Datenqualität und den Umfang der Anwendung der jeweiligen LCI Ergebnisse bzw. der Datensätze. Der Datensatz repräsentiert den Stand der Technik bezogen auf die funktionelle Einheit. does not look like a valid URI, trying to serialize this will break.
# EN 15804+A2 (EF 3.0) does not look like a valid URI, trying to serialize this will break.
# 119 IW Stahlbeton, C25/30, 30cm, Bewehrung 100kg/m3, Schaltung glatt does not look like a valid URI, trying to serialize this will break.
# Produktkategorieregeln Teil A does not look like a valid URI, trying to serialize this will break.
# Innhold av biogent karbon i produkt does not look like a valid URI, trying to serialize this will break.
# m3 world eq. deprived does not look like a valid URI, trying to serialize this will break.
# kg CO2-Äqv. does not look like a valid URI, trying to serialize this will break.
# kg N eqv. does not look like a valid URI, trying to serialize this will break.
# Acidification potential, Accumulated Exceedance (AP) does not look like a valid URI, trying to serialize this will break.
# Die dosierten Gesteinskörnungen werden zunächst trocken mit Zement als Bindemittel und weiteren Zusatzstoffen vorgemischt. Danach wird die Mischung mit Wasser zu einem plastisch verformbaren Frischbeton gemischt.
#
# Dieser wird ohne Lagerung mit Betonfahrmischern auf die Baustelle transportiert und dort in die vorbereitete Schalung (i. d. R. mit Bewehrung) eingebracht und verdichtet.
#
# Zur Sicherung der Betonqualität ist ein Qualitätssicherungssystem im Werk Coesfeld installiert, das sich an den Anforderungen an die werkseigene Produktionskontrolle in BS 8500 und DIN 1045-2 orientiert.  does not look like a valid URI, trying to serialize this will break.
# 012 GR Unterbau, gedämmt, XPS 100, Sauberkeitsschicht, Trennlage does not look like a valid URI, trying to serialize this will break.
# Total nicht erneuerbare Primärenergie (PENRT) does not look like a valid URI, trying to serialize this will break.
# Colabeton S.p.A.  does not look like a valid URI, trying to serialize this will break.
# Global Warming Potential - fossil fuels (GWP-fossil) does not look like a valid URI, trying to serialize this will break.
# Materials for recycling (MFR) does not look like a valid URI, trying to serialize this will break.
# Mineralische Baustoffe does not look like a valid URI, trying to serialize this will break.
# Ready mixed concrete does not look like a valid URI, trying to serialize this will break.
# Betongen er produsert iht. NS-EN 206:2013+A2+NA does not look like a valid URI, trying to serialize this will break.
#  CLS Rck30 S4 XC2 D25 CEM IV 32,5 N-LH/SR CAM  does not look like a valid URI, trying to serialize this will break.
# Außenwand der Kellerwand, aus Stahlbeton C25/30, wasserundurchlässig, Bewehrung 100 kg/m3, mit glatter Schalung, 20 cm does not look like a valid URI, trying to serialize this will break.
# Depletion potential of the stratospheric ozone layer (ODP) does not look like a valid URI, trying to serialize this will break.
# Net use of fresh water (FW) does not look like a valid URI, trying to serialize this will break.
# Use of renewable primary energy as energy carrier (PERE) does not look like a valid URI, trying to serialize this will break.
# Aurland Energibygg AS does not look like a valid URI, trying to serialize this will break.
# Beton C20/25 XC1 XC2 F3 16 M EcoPact, Rezept Nummer DI3234-BHFS Version 1, Transportbetonwerk Dortmund-Schüren, Germany does not look like a valid URI, trying to serialize this will break.
# Use of non renewable secondary fuels (NRSF) does not look like a valid URI, trying to serialize this will break.
#  CFA70 Rck30 SF2 XC2 D10 CEM IV 42,5 R CAM does not look like a valid URI, trying to serialize this will break.
# Erneuerbare Primärenergie als Energieträger (PERE) does not look like a valid URI, trying to serialize this will break.
# Supports, columns, pylons and pillars on the inside of a structure with a slenderness ratio < 1:4. does not look like a valid URI, trying to serialize this will break.
# Nicht-erneuerbare Primärenergie als Energieträger (PENRE) does not look like a valid URI, trying to serialize this will break.
# Globalt oppvarmingspotensial arealbruk endringer i bruk av arealer (GWP-luluc) does not look like a valid URI, trying to serialize this will break.
# Potenzielles Auftreten von Krankheiten aufgrund von Feinstaubemissionen (PM) does not look like a valid URI, trying to serialize this will break.
# Eutrophication potential - freshwater (EP-freshwater) does not look like a valid URI, trying to serialize this will break.
# Abiotisk utarmingspotensial for fossile ressurser, fosile brensler (ADP-fossil) does not look like a valid URI, trying to serialize this will break.
# mol N eqv. does not look like a valid URI, trying to serialize this will break.
# m^3 does not look like a valid URI, trying to serialize this will break.
# Komponenten für die Wiederverwendung (CRU) does not look like a valid URI, trying to serialize this will break.
# 224 DA flach, Stahlbetondecke, C25/30, 20cm, Bewehrung 80kg/m3 does not look like a valid URI, trying to serialize this will break.
# EPD-IES-0013906:001 (S-P-13906)  beForce Rck50 S5 XC3 D20 CEM II 42,5 R CAM20 does not look like a valid URI, trying to serialize this will break.
# Total use of renewable primary energy resource (PERT) does not look like a valid URI, trying to serialize this will break.
# Institut Bauen und Umwelt e.V. does not look like a valid URI, trying to serialize this will break.
# kg CFC11 eqv. does not look like a valid URI, trying to serialize this will break.
# Europhication potential - freshwater (EP-freshwater) does not look like a valid URI, trying to serialize this will break.
# kg Sb-eqv. does not look like a valid URI, trying to serialize this will break.
#  UK average C32/40 CEM I Ready-mixed concrete does not look like a valid URI, trying to serialize this will break.
# Beton ist im Bauwesen ein vielfältig eingesetzter Baustoff. Er findet Anwendung im Hochbau vor allem für Decken, Wände, Treppen, Fundamente, Stützen und Binder, im Tiefbau bei erdberührten Bauteilen, Fundamenten, Bodenplatten, Bohrpfählen und im Ingenieurbau z.B. bei Brücken. does not look like a valid URI, trying to serialize this will break.
# Total bruk av fornybar primærenergi (TPE) does not look like a valid URI, trying to serialize this will break.
# EPD-IES-0013565:001 (S-P-13565)  CLS RCK35 S4 XC2 D25 CEM III 42,5 N LH-SR CAM does not look like a valid URI, trying to serialize this will break.
# Globalt oppvarmingspotensial -totalt (GWPtotal) does not look like a valid URI, trying to serialize this will break.
# 032 GR Unterbau, gedämmt, XPS 150, Sauberkeitsschicht, Trennlage does not look like a valid URI, trying to serialize this will break.
# Construction products (EN 15804A2) does not look like a valid URI, trying to serialize this will break.
# Toksisitet påvirkning på mennesker, kreft (HTP-c) does not look like a valid URI, trying to serialize this will break.
# mol H^(+) eqv. does not look like a valid URI, trying to serialize this will break.
# kBq U235 eqv. does not look like a valid URI, trying to serialize this will break.
# Frischwasserverbrauch (FW) does not look like a valid URI, trying to serialize this will break.
# EPD-IES-0013655:002 (S-P-13655)  CLS Rck20 S4 X0 D25 CEM IV 32,5 N-LH/SR CAM does not look like a valid URI, trying to serialize this will break.
# kg P eq. does not look like a valid URI, trying to serialize this will break.
# Building products made of concrete and concrete elements - Firmengruppe Max Bögl - Concrete C30/37 ground granulated blast furnace slag does not look like a valid URI, trying to serialize this will break.
# Abbaupotenzial der stratosphärischen Ozonschicht (ODP) does not look like a valid URI, trying to serialize this will break.
# Road traffic systems does not look like a valid URI, trying to serialize this will break.
# EPD-IES-0014097:001 (S-P-14097)  CFA70 Rck30 SF2 XC2 D10 CEM IV 42,5 R CAM does not look like a valid URI, trying to serialize this will break.
# Data quality:
# Specific data for the product composition are provided by the manufacturer. The data represent the production of the declared product and were collected for EPD development in the year of study. Background data is based on EPDs according to EN 15804 and different LCA databases. The data quality of the raw materials in A1 is presented in the table below.
#
# Allocation:
# The allocation is made in accordance with the provisions of EN 15804. Incoming energy and water and waste production in-house is allocated equally among all products through mass allocation. Effects of primary production of recycled materials is allocated to the main product in which the material was used. The recycling process and transportation of the material is allocated to this analysis.
#
# Cut-off criteria:
# All major raw materials and all the essential energy is included. The production processes for raw materials and energy flows with very small amounts (less than 1%) are not included. These cut-off criteria do not
# apply for hazardous materials and substances.
#  does not look like a valid URI, trying to serialize this will break.
# Globales Erwärmungspotenzial - fossil (GWP-fossil) does not look like a valid URI, trying to serialize this will break.
# B30 M60 D22 25% red does not look like a valid URI, trying to serialize this will break.
# Innenwand aus Stahlbeton mit Ortbeton, C25/30, 15cm, Bewehrung 80kg/m3 und glatter Schalung does not look like a valid URI, trying to serialize this will break.
# Medium Strength Concrete does not look like a valid URI, trying to serialize this will break.
# Innhold av biogent karbon i emballasjen does not look like a valid URI, trying to serialize this will break.
# kg CFC 11 eqv. does not look like a valid URI, trying to serialize this will break.
# Concrete is produced by mixing cement, aggregates (sand, crushed stone and gravel), water and additives. The cement section is  consists  of storage silos connected to a weighbridge, the extraction and loading of the cement into the truck mixer takes place via closed augers. The suction system and filters guarantee the abatement of dust during  loading of the truck mixers.  The coarse aggregate (“Gravel” or commercially “Cobblestone”) is unloaded directly into a hopper from the tipper trucks owned by the supplier and is then transferred by means of belts from the hopper on the ground to the loading ones. The same applies  for sand. The additives are dosed separately using volumetric dosers, whereas the mixing water is dosed with electromechanical meters. All the components described above are conveyed into the concrete mixer barrel where the homogenization and mixing phases take  place; the energy required for the production of concrete is given by electricity. The shipment of the final product is carried out using special truck mixers. The concretes subject to analysis comply with the requirements of the REACH regulation. does not look like a valid URI, trying to serialize this will break.
# CLS Rck30 S4 XC2 D25 CEM IV 32,5 N-LH/SR CAM  does not look like a valid URI, trying to serialize this will break.
# conversion factor to 1 kg does not look like a valid URI, trying to serialize this will break.
# Components for re-use (CRU) does not look like a valid URI, trying to serialize this will break.
# Eksportert elektrisk energi(EEE) does not look like a valid URI, trying to serialize this will break.
# Structural concrete for civil buildings and constructions. does not look like a valid URI, trying to serialize this will break.
# kg Sb eq. does not look like a valid URI, trying to serialize this will break.
# Eco-toxicity - freshwater (ETP-fw) does not look like a valid URI, trying to serialize this will break.
# Bundesinstitut für Bau-, Stadt- und Raumforschung (BBSR) im Bundesamt für Bauwesen und Raumordnung (BBR) does not look like a valid URI, trying to serialize this will break.
# Toksisitet påvirkning på mennesker, andre effekter enn kreft (HTP-nc)  does not look like a valid URI, trying to serialize this will break.
# Unicon A/S does not look like a valid URI, trying to serialize this will break.
# Disease incidence does not look like a valid URI, trying to serialize this will break.
# Gründung, Fundamentplatte, Ortbeton C30/37, wasserundurchlässig, 25 cm, Bewehrung 140kg/m3, Randschalung does not look like a valid URI, trying to serialize this will break.
# Overall category for interior vertical structural components. does not look like a valid URI, trying to serialize this will break.
# Ferdig betong does not look like a valid URI, trying to serialize this will break.
# Die dosierten Gesteinskörnungen werden zunächst trocken mit Zement als Bindemittel und weiteren Zusatzstoffen vorgemischt. Danach wird die Mischung mit Wasser zu einem plastisch verformbaren Frischbeton gemischt.
#
# Dieser wird ohne Lagerung mit Betonfahrmischern auf die Baustelle transportiert und dort in die vorbereitete Schalung (i. d. R. mit Bewehrung) eingebracht und verdichtet.
#
# Zur Sicherung der Betonqualität ist ein Qualitätssicherungssystem im Werk Herne installiert, das sich an den Anforderungen an die werkseigene Produktionskontrolle in BS 8500 und DIN 1045-2 orientiert.  does not look like a valid URI, trying to serialize this will break.
# Mörtel und Beton does not look like a valid URI, trying to serialize this will break.
# layer thickness does not look like a valid URI, trying to serialize this will break.
# Fornybar primærenergi brukt som energibærer (RPEE) does not look like a valid URI, trying to serialize this will break.
# Carbon content (biogenic) does not look like a valid URI, trying to serialize this will break.
# CLS Rck20 S4 X0 D25 CEM IV 32,5 N-LH/SR CAM  does not look like a valid URI, trying to serialize this will break.
# "Cradle to gate with options" UNI EN 15804:2021 (EN 15804:2012+A2:2019 and EN 15804:2012+A2:2019+AC:2021).
# Included: A1, A2, A3, B1, B2, B3, B4, B5, B6, B7, C1, C2, C3, C4, D.
# Not declared: A4, A5. does not look like a valid URI, trying to serialize this will break.
# Loadbearing internal walls and large-area components that are necessary to ensure the stability of the structure, including horizontal waterproofing and chases and penetrations. does not look like a valid URI, trying to serialize this will break.
# Overgjødslingspotensial til ferskvann (EP-freshwater) does not look like a valid URI, trying to serialize this will break.
# EPD Data Format Extension does not look like a valid URI, trying to serialize this will break.
# Beton C16/20 XC1 XC2 F3 8 M ECOPact, Rezept Nummer DI2134-BHZK, Transportbetonwerk Düsseldorf-Rath, Germany does not look like a valid URI, trying to serialize this will break.
# Avhendet radioaktivt avfall (RW) does not look like a valid URI, trying to serialize this will break.
# Außenwand der Kellerwand, aus Stahlbeton C25/30, Bewehrung 100 kg/m3, mit rauer Schalung, 20 cm does not look like a valid URI, trying to serialize this will break.
# EPD-IES-0013699:001 (S-P-13699)  CLS Rck30 S4 XC2 D25 CEM IV 32,5 N-LH/SR CAM does not look like a valid URI, trying to serialize this will break.
# 011 GR Bodenplatte, Stahlbeton, C25/30, 20cm, Bewehrung 80kg/m3 does not look like a valid URI, trying to serialize this will break.
# Building products made of concrete and concrete elements - Firmengruppe Max Bögl - Concrete C30/37 blast furnace cement does not look like a valid URI, trying to serialize this will break.
# Potenzial für die Verknappung abiotischer Ressourcen – nicht fossile Ressourcen (ADPE) does not look like a valid URI, trying to serialize this will break.
# m3 world eqv. does not look like a valid URI, trying to serialize this will break.
# Dieses Dokument bezieht sich auf die Produktion im Werk Büttelborn der Holcim (Deutschland) GmbH in Germany does not look like a valid URI, trying to serialize this will break.
# Photochemical Ozone Creation Potential  (POCP) does not look like a valid URI, trying to serialize this will break.
# Økotoksisitet, ferskvann (ETP-fw) does not look like a valid URI, trying to serialize this will break.
# The life cycle assessment results cover the life cycle stages of manufacturing the intermediate products up to raw material extraction and processing operations of secondary materials serving as input (e.g. recycling processes), their transports to the plant as well as the production itself, including the provision of all auxiliary and operating materials, energy, and the complete waste treatment or landfilling of the residual waste during the stage of production. Modules A1, A2, and A3 are shown here as one aggregated module A1-A3. If further modules were calculated for this data set, they can be found separately and can be combined for a consideration of the entire life cycle. does not look like a valid URI, trying to serialize this will break.
# Beton C12/15 X0 F3 32 L ECOPact, Rezept Nummer DU1332-AHZK+CEMIIIB, Transportbetonwerk Mülheim, Germany does not look like a valid URI, trying to serialize this will break.
# Decke, Stahlbeton, Ortbeton C25/30, Schalung, Bewehrung, 100 kg/m3, 20 cm does not look like a valid URI, trying to serialize this will break.
# Decke, Stahlbeton, Ortbeton C25/30, Schalung, Bewehrung, 100 kg/m3, 25 cm does not look like a valid URI, trying to serialize this will break.
# Gründung, Fundamentplatte, Ortbeton C30/37, wasserundurchlässig, 40 cm, Bewehrung 140kg/m3, Randschalung does not look like a valid URI, trying to serialize this will break.
# Process flow does not look like a valid URI, trying to serialize this will break.
# ANLÆGSBETON (C40/50 Slump Concrete in Extra Aggressive Environmental Exposure Class) does not look like a valid URI, trying to serialize this will break.
# Bildungspotenzial für troposphärisches Ozon (POCP) does not look like a valid URI, trying to serialize this will break.
# jährlicher Durchschnitt does not look like a valid URI, trying to serialize this will break.
# Use of non renewable primary energy (PENRE) does not look like a valid URI, trying to serialize this will break.
# Input of secondary material (SM) does not look like a valid URI, trying to serialize this will break.
# Annual average does not look like a valid URI, trying to serialize this will break.
# Die dosierten Gesteinskörnungen werden zunächst trocken mit Zement als Bindemittel und weiteren Zusatzstoffen vorgemischt. Danach wird die Mischung mit Wasser zu einem plastisch verformbaren Frischbeton gemischt.
#
# Dieser wird ohne Lagerung mit Betonfahrmischern auf die Baustelle transportiert und dort in die vorbereitete Schalung (i. d. R. mit Bewehrung) eingebracht und verdichtet.
#
# Zur Sicherung der Betonqualität ist ein Qualitätssicherungssystem im Werk Düsseldorf-Rath installiert, das sich an den Anforderungen an die werkseigene Produktionskontrolle in BS 8500 und DIN 1045-2 orientiert.  does not look like a valid URI, trying to serialize this will break.
# Partikkelutslipp (PM) does not look like a valid URI, trying to serialize this will break.
# Bauprodukte aus Beton und Betonelemente - Firmengruppe Max Bögl - Beton C30/37 Hochofenzement does not look like a valid URI, trying to serialize this will break.
# Datakvalitet:
# Spesifikke data for produktsammensetningen er fremskaffet av produsenten.  De representerer produksjonen av det deklarerte produktet og ble samlet inn for EPD-­utvikling i det oppgitte året for studien.  Bakgrunnsdata er basert på EPDer iht. EN 15804 og ulike LCA­ databaser.  Datakvaliteten for råmaterialene i A1 er presentert i tabellen nedenfor.
#
# Allokering:
# Allokering er gjort iht. bestemmelser i EN 15804. Inngående energi og vann, samt produksjon av avfall i egen produksjon er allokert likt mellom alle produktene gjennom masseallokering. Miljøpåvirkning og ressursforbruk for primærproduksjonen av resirkulerte materialer er allokert til det opprinnelige produktsystemet. Bearbeidingsprosessen og transport av materialet til produksjonssted er allokert til analysen i denne EPDen.
#
# Cut-off kriterier:
# Alle viktige råmaterialer og all viktig energibruk er inkludert. Produksjonsprosessen for råmaterialene og energistrømmer som inngår med veldig små mengder (mindre enn 1%) er ikke inkludert. Disse cut-off kriteriene gjelder ikke for farlige materialer og stoffer.
#  does not look like a valid URI, trying to serialize this will break.
# Particulate Matter emissions (PM) does not look like a valid URI, trying to serialize this will break.
# Europhication potential - marine (EP-marine) does not look like a valid URI, trying to serialize this will break.
# EPD-IES-0013699:001 (S-P-13699) does not look like a valid URI, trying to serialize this will break.
# kg Sb eqv. does not look like a valid URI, trying to serialize this will break.
# m^(3) world eqv. does not look like a valid URI, trying to serialize this will break.
# Beton C20/25 XC1 XC2 F3 16 M Ecopact, Rezept Nummer DI3234-BHFS Version 1, Transportbetonwerk Herne, Germany does not look like a valid URI, trying to serialize this will break.
# Abiotisk utarmingspotensial for ikke-fossile ressurser, mineraler (ADP-elements) does not look like a valid URI, trying to serialize this will break.
# Gesamtverbrauch von erneuerbarer Primärenergie (PERT) does not look like a valid URI, trying to serialize this will break.
# GaBi Database (SP40) does not look like a valid URI, trying to serialize this will break.
# 356 DE Stahlbeton, Ortbeton, C25/30, 25cm, Bewehrung 100kg/m3 does not look like a valid URI, trying to serialize this will break.
# Decke, Brettsperrholz, 120 mm, gehobelt, mit Trennlage, Aufbeton, 18 cm does not look like a valid URI, trying to serialize this will break.
# 118 IW Stahlbeton, C25/30, 20cm, Bewehrung 80kg/m3, Schaltung glatt does not look like a valid URI, trying to serialize this will break.
# Beton C20/25 XC1 XC2 F3 16 M ECOPact, Rezept Nummer DI3234-BHFS Version 1, Transportbetonwerk Lüdenscheid-Freisenberg, Germany does not look like a valid URI, trying to serialize this will break.
# 226 DA Stahlbeton, Fertigteil, Aufbeton, 20cm, Bewehrung 80kg/m3 does not look like a valid URI, trying to serialize this will break.
# Potenzielle Toxizitätsvergleichseinheit für Ökosysteme (ETP-fw) does not look like a valid URI, trying to serialize this will break.
# 453 DA flach, Stahlbetondecke, C25/30, 25cm, Bewehrung 120kg/m3 does not look like a valid URI, trying to serialize this will break.
# Außenwand der Kellerwand, aus Stahlbeton C30/37, wasserundurchlässig, Bewehrung 120 kg/m3, mit raue Schalung, 25 cm does not look like a valid URI, trying to serialize this will break.
# Materials for Recycling (MFR) does not look like a valid URI, trying to serialize this will break.
# External columns does not look like a valid URI, trying to serialize this will break.
# EPD-IES-0013565:001 (S-P-13565) does not look like a valid URI, trying to serialize this will break.
# 369 DE Stahlbeton, Ortbeton, C25/30, 30cm, Bewehrung 120kg/m3 does not look like a valid URI, trying to serialize this will break.
# Dieses Dokument bezieht sich auf die Produktion im Werk Mülheim der Holcim (Deutschland) GmbH in Germany does not look like a valid URI, trying to serialize this will break.
# kg Sb-Äqv. does not look like a valid URI, trying to serialize this will break.
# Non-hazardous waste disposed (NHWD) does not look like a valid URI, trying to serialize this will break.
# Firmengruppe Max Bögl does not look like a valid URI, trying to serialize this will break.
# Erneuerbare Primärenergie zur stofflichen Nutzung (PERM) does not look like a valid URI, trying to serialize this will break.
# Produktkategorieregeln Teil B – für Bauprodukte aus Beton und Betonelemente does not look like a valid URI, trying to serialize this will break.
# ISO 21930 does not look like a valid URI, trying to serialize this will break.
# Dieses Dokument bezieht sich auf die Produktion im Werk Unna der Holcim (Deutschland) GmbH in Germany does not look like a valid URI, trying to serialize this will break.
# Globales Erwärmungspotenzial - total (GWP-total) does not look like a valid URI, trying to serialize this will break.
# Europhication potential - terrestrial (EP-terrestrial) does not look like a valid URI, trying to serialize this will break.
# Beton wird hergestellt durch Mischen von Zement,
# grober und feiner Gesteinskörnung und Wasser, mit oder ohne Zugabe von Zusatzmitteln, Zusatzstoffen oder Fasern.
#
# Der Frischbeton wird in Schalungen eingebracht, verdichtet und erhärtet durch die Hydratation des Zements zu einem festen künstlichen Gestein.
#  does not look like a valid URI, trying to serialize this will break.
# Potenzielle Wirkung durch Exposition des Menschen mit U235 (IRP) does not look like a valid URI, trying to serialize this will break.
# Betong B30 M60 er ferdigbetong produsert av Hjelmeset Betong AS.
# Betongen benyttes til alle typer konstruksjoner som gulv og vegger . Betongen består av sement vann singel sand og tillsetningsstoff does not look like a valid URI, trying to serialize this will break.
# EPD-IES-0012797:001 (S-P-12797)  CLS Rck35 S5 XC2 D25 CEM IV 42,5 R SR CAM does not look like a valid URI, trying to serialize this will break.
# Your use of this material is subject to the General Terms of Use published on by EPD International AB:s homepage at https://www.environdec.com/contact/General-terms-of-use/. If you have not accepted EPD International AB:s the General Terms of Use, you are not authorized to exploit this work in any manner. does not look like a valid URI, trying to serialize this will break.
# Ikke fornybar primærenergi brukt som råmateriale (NRPM) does not look like a valid URI, trying to serialize this will break.
# Materialer for energigjenvinning (MER) does not look like a valid URI, trying to serialize this will break.
# Dach, flach / lach geneigt, aus Stahlbeton, als Elementdecke mit Fertigteil und Aufbeton, Bewehrung 100 kg/m3, 25 cm does not look like a valid URI, trying to serialize this will break.
# Dieses Dokument bezieht sich auf die Produktion des Betons mit folgenden Eigenschaften C20/25 X0 C1 16 L EcoPact, Rezept Nummer DU3212-AHZS , hergestellt im Betonwerk Ginsheim-Gustavsburg der Firma Holcim (Deutschland) GmbH für die Verwendung als Beton für normalen Hochbau und Infrastrukturbau.
#
# Typ der EPD: von der Wiege bis zum Werkstor mit Optionen, Module C1-C4 und Modul D (A1-A3 + C + D und zusätzliche Module A4, A5 und B1)
#
# Die gewählten Systemgrenzen umfassen die Herstellung des Betons einschließlich der Rohstoffgewinnung, dessen Einbau und Nutzung bis zur Entsorgung des fertigen Produkts.
#
# Modul A1: Gewinnung und Aufbereitung der Betonausgangsstoffe
# Modul A2: Transport der Rohstoffe zum Betonwerk
# Modul A3: Betonherstellung im Werk und Abfallbehandlung
# Modul A4: Transport zur Baustelle
# Modul A5: Beinhaltet alle mit dem Einbau des Betons verbundenen Prozesse (z.B. Pumpen oder Kübeleinbau auf der Baustelle) sowie die Herstellung, den Transport und die Behandlung von nicht verwendetem Beton (z.B. Rückbeton)
# Modul B1: Carbonatisierung während der Nutzungsphase
# Modul B2-B7: Für Betonbauteile sind Instandhaltungs- und Reparaturmaßnahmen während der Referenznutzungsdauer i. d. R. nicht erforderlich, so dass in diesen Modulen keine Umweltlasten anfallen
# Modul C1: Rückbau / Abbruch von Betongebäuden / -bauteilen
# Modul C2: Transport von Betonabbruch zur Aufbereitung
# Modul C3: Brechen von Beton
# Modul D: Gutschriften und Lasten für die Nutzung von Betonabbruch als Ersatz für Primärmaterial does not look like a valid URI, trying to serialize this will break.
# Beton C20/25 XC1 XC2 F3 16 M EcoPact, Rezept Nummer DI3234-BHFS Version 1, Transportbetonwerk Lünen, Germany does not look like a valid URI, trying to serialize this will break.
# Ionizing radiation, human health (IRP) does not look like a valid URI, trying to serialize this will break.
# A1,A2,A3,A4 og C1-C4 og D does not look like a valid URI, trying to serialize this will break.
# Total use of non-renewable primary energy resources (PENRT) does not look like a valid URI, trying to serialize this will break.
# Die dosierten Gesteinskörnungen werden zunächst trocken mit Zement als Bindemittel und weiteren Zusatzstoffen vorgemischt. Danach wird die Mischung mit Wasser zu einem plastisch verformbaren Frischbeton gemischt.
#
# Dieser wird ohne Lagerung mit Betonfahrmischern auf die Baustelle transportiert und dort in die vorbereitete Schalung (i. d. R. mit Bewehrung) eingebracht und verdichtet.
#
# Zur Sicherung der Betonqualität ist ein Qualitätssicherungssystem im Werk Büttelborn installiert, das sich an den Anforderungen an die werkseigene Produktionskontrolle in BS 8500 und DIN 1045-2 orientiert.  does not look like a valid URI, trying to serialize this will break.
# Ikke fornybar primærenergi brukt som energibærer (NRPE) does not look like a valid URI, trying to serialize this will break.
# Eutrophierungspotenzial - Land (EP-terrestrial) does not look like a valid URI, trying to serialize this will break.
# Beton C20/25 XC1 XC2 F3 16 M EcoPact, Rezept Nummer DI3234-BHFS Version 1, Transportbetonwerk Frankfurt, Germany does not look like a valid URI, trying to serialize this will break.
# Eutrophierungspotenzial - Süßwasser (EP-freshwater) does not look like a valid URI, trying to serialize this will break.
# Volum  does not look like a valid URI, trying to serialize this will break.
# Dach, flach / flach geneigt, aus Stahlbeton, als Elementdecke mit Fertigteil und Aufbeton, Bewehrung 80 kg/m3, 20 cm does not look like a valid URI, trying to serialize this will break.
# Potensial for fotokjemisk oksidantdanning (POCP) does not look like a valid URI, trying to serialize this will break.
# Beton C20/25 X0 C1 22 M, Rezept Nummer OA3314-ANZS, Transportbetonwerk Herborn-Burg, Germany does not look like a valid URI, trying to serialize this will break.
# Transportbeton C20/25 does not look like a valid URI, trying to serialize this will break.
# EPD Deklarationsnummer  does not look like a valid URI, trying to serialize this will break.
# Roof structures does not look like a valid URI, trying to serialize this will break.
# 188 DE Holz, Brettsperrholz, 120mm, gehobelt, Aufbeton, 18cm does not look like a valid URI, trying to serialize this will break.
# Exportierte thermische Energie (EET) does not look like a valid URI, trying to serialize this will break.
# Dieser Datensatz beinhaltet die Ergebnisse für die Module A1-A3 sowie die Module C1, C2, C3, C4 und D gemäß EN 15804 + A2.
# Ein Vergleich mit anderen Produkten ist nur mit einer vergleichbaren Anwendung im Gebäude zulässig. Grundsätzlich ist eine Gegenüberstellung oder die Bewertung von EPD Daten nur möglich, wenn alle zu vergleichenden Datensätze nach EN 15804 + A2 erstellt wurden und der Gebäudekontext, bzw. die produktspezifischen Leistungsmerkmale berücksichtigt werden. does not look like a valid URI, trying to serialize this will break.
# Beton C20/25 X0 C1 22 M EcoPact, Rezept Nummer DU3312-AHZS, Transportbetonwerk Mainz, Germany does not look like a valid URI, trying to serialize this will break.
# Overgjødslingspotensial til jord (EP-terrestrial) does not look like a valid URI, trying to serialize this will break.
# ecoinvent database (all versions) does not look like a valid URI, trying to serialize this will break.
# Dieses Dokument bezieht sich auf die Produktion im Werk Lünen der Holcim (Deutschland) GmbH in Germany does not look like a valid URI, trying to serialize this will break.
# Beton C20/25 X0 C1 16 L, Rezept Nummer NU3212-AHZS, Transportbetonwerk Coesfeld, Germany does not look like a valid URI, trying to serialize this will break.
# Dieses Dokument bezieht sich auf die Produktion im Werk Dortmund-Schüren der Holcim (Deutschland) GmbH in Germany does not look like a valid URI, trying to serialize this will break.
# EPD-IES-0015590:001  CLS Rck15 S4 X0 D25 CEM/III B 42,5 N-LH/SR CAM does not look like a valid URI, trying to serialize this will break.
# Forsurningspotensial for kilder på land og vann (AP) does not look like a valid URI, trying to serialize this will break.
# kg NMVOC eq. does not look like a valid URI, trying to serialize this will break.
# Land use related impacts/Soil quality (SQP) does not look like a valid URI, trying to serialize this will break.
# Dieses Dokument bezieht sich auf die Produktion des Betons mit folgenden Eigenschaften C12/15 X0 F3 32 L ECOPact, Rezept Nummer DU1332-AHZK+CEMIIIB , hergestellt im Betonwerk Mülheim der Firma Holcim (Deutschland) GmbH für die Verwendung als Beton für normalen Hochbau und Infrastrukturbau.
#
# ...
# Modul B1: Carbonatisierung während der Nutzungsphase
# Modul B2-B7: Für Betonbauteile sind Instandhaltungs- und Reparaturmaßnahmen während der Referenznutzungsdauer i. d. R. nicht erforderlich, so dass in diesen Modulen keine Umweltlasten anfallen
# Modul C1: Rückbau / Abbruch von Betongebäuden / -bauteilen
# Modul C2: Transport von Betonabbruch zur Aufbereitung
# Modul C3: Brechen von Beton
# Modul D: Gutschriften und Lasten für die Nutzung von Betonabbruch als Ersatz für Primärmaterial does not look like a valid URI, trying to serialize this will break.
# 364 DE Stahlbeton, Ortbeton, C25/30, 30cm, Bewehrung 120kg/m3 does not look like a valid URI, trying to serialize this will break.
# Die dosierten Gesteinskörnungen werden zunächst trocken mit Zement als Bindemittel und weiteren Zusatzstoffen vorgemischt. Danach wird die Mischung mit Wasser zu einem plastisch verformbaren Frischbeton gemischt.
#
# Dieser wird ohne Lagerung mit Betonfahrmischern auf die Baustelle transportiert und dort in die vorbereitete Schalung (i. d. R. mit Bewehrung) eingebracht und verdichtet.
#
# Zur Sicherung der Betonqualität ist ein Qualitätssicherungssystem im Werk Mainz installiert, das sich an den Anforderungen an die werkseigene Produktionskontrolle in BS 8500 und DIN 1045-2 orientiert.  does not look like a valid URI, trying to serialize this will break.
# Dieses Dokument bezieht sich auf die Produktion im Werk Mainz der Holcim (Deutschland) GmbH in Germany does not look like a valid URI, trying to serialize this will break.
# 060 AW Stahlbeton, 20cm, Bewehrung 80kg/m3, Schalung glatt does not look like a valid URI, trying to serialize this will break.
# 035 GR Fundamentplatte, Stahlbeton, C30/37, WU, 40cm, Bewehrung 140kg/m3 does not look like a valid URI, trying to serialize this will break.
# 180 DE Stahlbeton, Ortbeton, C25/30, 25cm, Bewehrung 100kg/m3 does not look like a valid URI, trying to serialize this will break.
# 015 GR Bodenplatte, Stahlbeton, C25/30, 25cm, Bewehrung 100kg/m3 does not look like a valid URI, trying to serialize this will break.
# Dieses Dokument bezieht sich auf die Produktion des Betons mit folgenden Eigenschaften C20/25 XC1 XC2 F3 16 M Ecopact, Rezept Nummer DI3234-BHFS  Version 1, hergestellt im Betonwerk Herne der Firma Holcim (Deutschland) GmbH für die Verwendung als Beton für normalen Hochbau und Infrastrukturbau.
#
# Typ der EPD: von der Wiege bis zum Werkstor mit Optionen, Module C1-C4 und Modul D (A1-A3 + C + D und zusätzliche Module A4, A5 und B1)
#
# Die gewählten Systemgrenzen umfassen die Herstellung des Betons einschließlich der Rohstoffgewinnung, dessen Einbau und Nutzung bis zur Entsorgung des fertigen Produkts.
#
# Modul A1: Gewinnung und Aufbereitung der Betonausgangsstoffe
# Modul A2: Transport der Rohstoffe zum Betonwerk
# Modul A3: Betonherstellung im Werk und Abfallbehandlung
# Modul A4: Transport zur Baustelle
# Modul A5: Beinhaltet alle mit dem Einbau des Betons verbundenen Prozesse (z.B. Pumpen oder Kübeleinbau auf der Baustelle) sowie die Herstellung, den Transport und die Behandlung von nicht verwendetem Beton (z.B. Rückbeton)
# Modul B1: Carbonatisierung während der Nutzungsphase
# Modul B2-B7: Für Betonbauteile sind Instandhaltungs- und Reparaturmaßnahmen während der Referenznutzungsdauer i. d. R. nicht erforderlich, so dass in diesen Modulen keine Umweltlasten anfallen
# Modul C1: Rückbau / Abbruch von Betongebäuden / -bauteilen
# Modul C2: Transport von Betonabbruch zur Aufbereitung
# Modul C3: Brechen von Beton
# Modul D: Gutschriften und Lasten für die Nutzung von Betonabbruch als Ersatz für Primärmaterial does not look like a valid URI, trying to serialize this will break.
# Jane Anderson does not look like a valid URI, trying to serialize this will break.
# B30 M60 Standardbetong, Dm 22 mm, synk 200, Schwenk Miljøsement B30 M60 Dm 22 mm synk 200 does not look like a valid URI, trying to serialize this will break.
# Dieses Dokument bezieht sich auf die Produktion des Betons mit folgenden Eigenschaften C20/25 XC1 XC2 F3 16 M ECOPact, Rezept Nummer DI3234-BHFS  Version 1, hergestellt im Betonwerk Balve der Firma Holcim (Deutschland) GmbH für die Verwendung als Beton für normalen Hochbau und Infrastrukturbau.
#
# Typ der EPD: von der Wiege bis zum Werkstor mit Optionen, Module C1-C4 und Modul D (A1-A3 + C + D und zusätzliche Module A4, A5 und B1)
#
# Die gewählten Systemgrenzen umfassen die Herstellung des Betons einschließlich der Rohstoffgewinnung, dessen Einbau und Nutzung bis zur Entsorgung des fertigen Produkts.
#
# Modul A1: Gewinnung und Aufbereitung der Betonausgangsstoffe
# Modul A2: Transport der Rohstoffe zum Betonwerk
# Modul A3: Betonherstellung im Werk und Abfallbehandlung
# Modul A4: Transport zur Baustelle
# Modul A5: Beinhaltet alle mit dem Einbau des Betons verbundenen Prozesse (z.B. Pumpen oder Kübeleinbau auf der Baustelle) sowie die Herstellung, den Transport und die Behandlung von nicht verwendetem Beton (z.B. Rückbeton)
# Modul B1: Carbonatisierung während der Nutzungsphase
# Modul B2-B7: Für Betonbauteile sind Instandhaltungs- und Reparaturmaßnahmen während der Referenznutzungsdauer i. d. R. nicht erforderlich, so dass in diesen Modulen keine Umweltlasten anfallen
# Modul C1: Rückbau / Abbruch von Betongebäuden / -bauteilen
# Modul C2: Transport von Betonabbruch zur Aufbereitung
# Modul C3: Brechen von Beton
# Modul D: Gutschriften und Lasten für die Nutzung von Betonabbruch als Ersatz für Primärmaterial does not look like a valid URI, trying to serialize this will break.
# 2019:14-c-PCR-003 Concrete and concrete elements (EN 16757) does not look like a valid URI, trying to serialize this will break.
# External walls and other components of small thickness compared with their other dimensions, that are necessary to ensure the stability of the structure, including horizontal damp-proofing as well as chases and penetrations does not look like a valid URI, trying to serialize this will break.
# Charlotte Merlin - FORCE Technology does not look like a valid URI, trying to serialize this will break.
# Dieses Dokument bezieht sich auf die Produktion im Werk Düsseldorf-Rath der Holcim (Deutschland) GmbH in Germany does not look like a valid URI, trying to serialize this will break.
# Dieses Dokument bezieht sich auf die Produktion im Werk Herborn-Burg der Holcim (Deutschland) GmbH in Germany does not look like a valid URI, trying to serialize this will break.
# Loadbearing and non-loadbearing components for flat and sloping roofs, and other horizontal components that enclose the top of the structure. does not look like a valid URI, trying to serialize this will break.
# Unit Value
# Compressive Strength (Cylinder) N / mm² 32.0
# Compressive Strength (Cube) N / mm² 40.0
# Gross Density kg / m³ 2312. does not look like a valid URI, trying to serialize this will break.
# 046 AW Stahlbeton, 25cm, Bewehrung 100kg/m3, Schalung glatt does not look like a valid URI, trying to serialize this will break.
#  CLS Rck35 S5 XC2 D25 CEM IV 42,5 R SR CAM does not look like a valid URI, trying to serialize this will break.
# 051 AW KG, Stahlbeton, WU, 30cm, Bewehrung 120kg/m3, Schalung glatt does not look like a valid URI, trying to serialize this will break.
# Light Weight Concrete does not look like a valid URI, trying to serialize this will break.
# Hjelmeset Betong AS does not look like a valid URI, trying to serialize this will break.
# United Kingdom does not look like a valid URI, trying to serialize this will break.
# "2024-09-17" - "2029-09-17" does not look like a valid URI, trying to serialize this will break.
# Density 2000–2600 kg/m³ does not look like a valid URI, trying to serialize this will break.
# Dieses Dokument bezieht sich auf die Produktion des Betons mit folgenden Eigenschaften C20/25 XC1 XC2 F3 16 M ECOPact, Rezept Nummer DI3234-BHFS  Version 1, hergestellt im Betonwerk Lüdenscheid-Freisenberg der Firma Holcim (Deutschland) GmbH für die Verwendung als Beton für normalen Hochbau und Infrastrukturbau.
#
# Typ der EPD: von der Wiege bis zum Werkstor mit Optionen, Module C1-C4 und Modul D (A1-A3 + C + D und zusätzliche Module A4, A5 und B1)
#
# Die gewählten Systemgrenzen umfassen die Herstellung des Betons einschließlich der Rohstoffgewinnung, dessen Einbau und Nutzung bis zur Entsorgung des fertigen Produkts.
#
# Modul A1: Gewinnung und Aufbereitung der Betonausgangsstoffe
# Modul A2: Transport der Rohstoffe zum Betonwerk
# Modul A3: Betonherstellung im Werk und Abfallbehandlung
# Modul A4: Transport zur Baustelle
# Modul A5: Beinhaltet alle mit dem Einbau des Betons verbundenen Prozesse (z.B. Pumpen oder Kübeleinbau auf der Baustelle) sowie die Herstellung, den Transport und die Behandlung von nicht verwendetem Beton (z.B. Rückbeton)
# Modul B1: Carbonatisierung während der Nutzungsphase
# Modul B2-B7: Für Betonbauteile sind Instandhaltungs- und Reparaturmaßnahmen während der Referenznutzungsdauer i. d. R. nicht erforderlich, so dass in diesen Modulen keine Umweltlasten anfallen
# Modul C1: Rückbau / Abbruch von Betongebäuden / -bauteilen
# Modul C2: Transport von Betonabbruch zur Aufbereitung
# Modul C3: Brechen von Beton
# Modul D: Gutschriften und Lasten für die Nutzung von Betonabbruch als Ersatz für Primärmaterial does not look like a valid URI, trying to serialize this will break.
# 324 DE Stahlbeton, Ortbeton, C25/30, 20cm, Bewehrung 100kg/m3 does not look like a valid URI, trying to serialize this will break.
# Supports, columns, pylons and pillars on the exterior side of a structure with a slenderness ratio < 1 : 4 does not look like a valid URI, trying to serialize this will break.
# CLS RCK15 S4 X0 D25 CEM IV 32,5 N LH-SR CAM does not look like a valid URI, trying to serialize this will break.
# 329 DE Stahlbeton, Ortbeton, C25/30, 20cm, Bewehrung 100kg/m3 does not look like a valid URI, trying to serialize this will break.
# Loadbearing and non-loadbearing components for floors and ceilings, stairs, ramps and other horizontal constructions does not look like a valid URI, trying to serialize this will break.
# 004 GR Unterbau, gedämmt, XPS 100, Sauberkeitsschicht, Trennlage does not look like a valid URI, trying to serialize this will break.
# Dieses Dokument bezieht sich auf die Produktion im Werk Herne der Holcim (Deutschland) GmbH in Germany does not look like a valid URI, trying to serialize this will break.
# This is a specific product EPD for the concrete type:
#
# Extra Aggressive 40 MPa SCC concrete with AALBORG SOLID cement (CEM II/A-V 42,5 N).
# This product-EPD covers all variants of this concrete type with and without pozzolans as fly ash and silica fume. This product-EPD also covers all available consistency and Dmax variants of the concrete type.
#
# This EPD does not cover the additional components as plastic or steel fibers, which can be requested to be added to the concrete by the costumer. An EPD for these components can be supplied separately upon request.
#
# For more information, see UNICON's publications:
# https://www.unicon.dk/produkter-services/publikationer/
#
#
# Year of Study is December 2022 to November 2023.
#  100% ready mixed concrete does not look like a valid URI, trying to serialize this will break.
#  CLS Rck20 S4 X0 D25 CEM IV 32,5 N-LH/SR CAM does not look like a valid URI, trying to serialize this will break.
# B30 M60 Dmax 22, Lavkarbon A  does not look like a valid URI, trying to serialize this will break.
# Loadbearing internal walls does not look like a valid URI, trying to serialize this will break.
# 138 IW Stahlbeton, C25/30, 15cm, Bewehrung 80kg/m3, Schalung glatt does not look like a valid URI, trying to serialize this will break.
# 007 GR Bodenplatte, Stahlbeton, C25/30, 20cm, Bewehrung 80kg/m3 does not look like a valid URI, trying to serialize this will break.
# Density > 2600 kg/m³ does not look like a valid URI, trying to serialize this will break.
# 054 AW KG, Stahlbeton, WU, 30cm, Bewehrung 120kg/m3, Schalung glatt does not look like a valid URI, trying to serialize this will break.
# Bygg og anlegg i Midt-Norge does not look like a valid URI, trying to serialize this will break.
# EPD-IES-0013648:002 (S-P-13648) does not look like a valid URI, trying to serialize this will break.
# Betonfertigteil Decke, 20cm does not look like a valid URI, trying to serialize this will break.
# Internal columns does not look like a valid URI, trying to serialize this will break.
# 031 GR Bodenplatte, Stahlbeton, C25/30, 30cm, Bewehrung 100kg/m3 does not look like a valid URI, trying to serialize this will break.
# Datakvalitet:
# Spesifikke data for produktsammensetningen er fremskaffet av produsenten.  De representerer produksjonen av det deklarerte produktet og ble samlet inn for EPD-­utvikling i det oppgitte året for studien.  Bakgrunnsdata er basert på EPDer iht. EN 15804 og ulike LCA­ databaser.  Datakvaliteten for råmaterialene i A1 er presentert i tabellen nedenfor.
# Spesifikke data for produktsammensetningen er fremskaffet av produsenten.
#
# Allokering:
# Allokering er gjort iht. bestemmelser i EN 15804. Inngående energi og vann, samt produksjon av avfall i egen produksjon er allokert likt mellom alle produktene gjennom masseallokering. Miljøpåvirkning og ressursforbruk for primærproduksjonen av resirkulerte materialer er allokert til det opprinnelige produktsystemet. Bearbeidingsprosessen og transport av materialet til produksjonssted er allokert til analysen i denne EPDen.
#
# Cut-off kriterier:
# Alle viktige råmaterialer og all viktig energibruk er inkludert. Produksjonsprosessen for råmaterialene og energistrømmer som inngår med veldig små mengder (mindre enn 1%) er ikke inkludert. Disse cut-off kriteriene gjelder ikke for farlige materialer og stoffer.
#  does not look like a valid URI, trying to serialize this will break.
# 334 DE Stahlbeton, Ortbeton, C25/30, 20cm, Bewehrung 100kg/m3 does not look like a valid URI, trying to serialize this will break.
# 030 GR Unterbau, gedämmt, XPS 240, Sauberkeitsschicht, Trennlage does not look like a valid URI, trying to serialize this will break.
# 028 GR Unterbau, gedämmt, XPS 100, Sauberkeitsschicht, Trennlage does not look like a valid URI, trying to serialize this will break.
# Heidelberg Materials Beton Danmark A/S does not look like a valid URI, trying to serialize this will break.
# Gründung, Unterbau für Bodenplatten, Sauberkeitsschicht aus Beton, Trennlage mit Folie does not look like a valid URI, trying to serialize this will break.
# 120 IW Stahlbeton, C25/30, 25cm, Bewehrung 120kg/m3, Schaltung rau does not look like a valid URI, trying to serialize this will break.
# 003 GR Bodenplatte, Stahlbeton, C25/30, 30cm, Bewehrung 100kg/m3 does not look like a valid URI, trying to serialize this will break.
#  CLS RCK15 S4 X0 D25 CEM IV 32,5 N LH-SR CAM does not look like a valid URI, trying to serialize this will break.
# Loadbearing components for floors and ceilings, stairs, ramps, balconies and other horizontal constructions including upstand and downstand beams, shoring and infill elements, (e. g. insulation,hollow blocks, false floors, loose fill). does not look like a valid URI, trying to serialize this will break.
# https://data.environdec.com/resource/sources/a0cddb88-13da-4670-8c3b-08dd1f3f8b98/SR CAM.pdf?version=00.00.001 does not look like a valid URI, trying to serialize this will break.
# Loadbearing constructions for roofs, canopies, roof trusses, space frames and dome roofs, including upstand and downstand beams, and infill elements (e. g. insulation, hollow blocks, false floors, loose fill) does not look like a valid URI, trying to serialize this will break.
# 047 AW Stahlbeton, 25cm, Bewehrung 120kg/m3, Schalung glatt does not look like a valid URI, trying to serialize this will break.
# "2024-10-21" - "2029-10-21" does not look like a valid URI, trying to serialize this will break.
# CLS Rck35 S3 XC2 D15 CEM IV 42,5 R SR CAM does not look like a valid URI, trying to serialize this will break.
# Dieses Dokument bezieht sich auf die Produktion im Werk Balve der Holcim (Deutschland) GmbH in Germany does not look like a valid URI, trying to serialize this will break.
# ✔ GraphML written to ttl_graph_ready_for_gephi.graphml — import in Gephi and run a layout.

# %%
# -------------------------------------------------------------
# TTL ➜ GraphML with hybrid coloring scheme for Gephi
#   • ilcd branches colored by section
#   • every other namespace gets its own color
# -------------------------------------------------------------
# pip install rdflib networkx matplotlib

import rdflib
import networkx as nx
from collections import deque
from matplotlib import cm
from matplotlib.colors import to_hex

# --- 1. File paths ---------------------------------------------------------
TTL_FILE = "../linkml/data/rdf/epd_rdf_instance_datastore_canonical_skos_din_bki_shacl.ttl"
OUT_FILE = "ttl_graph_hybrid_colors.graphml"

# --- 2. Section predicates (ilcd) -----------------------------------------
SECTION_PREDICATES = {
    "administrativeInformation": "admin",
    "exchanges": "exchanges",
    "lciaResults": "lcia",
    "modellingAndValidation": "modelling",
    "processInformation": "process",
}

# --- 3. Load RDF -----------------------------------------------------------
rdf = rdflib.Graph()
rdf.parse(TTL_FILE, format="turtle")

# Namespace URIs we care about
ns_mgr = rdf.namespace_manager
prefix_uri = {p: str(u) for p, u in ns_mgr.namespaces()}
ILCD_URI = prefix_uri["ilcd"]

# --- 4. Build NetworkX graph ----------------------------------------------
G = nx.DiGraph()
for s, p, o in rdf:
    G.add_edge(str(s), str(o), predicate=str(p))

# --- 5. Tag ilcd branches by section --------------------------------------
node_tag = {}                       # node ➜ tag string (section OR prefix)

# Collect start nodes for each ilcd section
start_nodes = []
for s, p, o in rdf:
    pred = str(p)
    if pred.startswith(ILCD_URI):
        local = pred[len(ILCD_URI):]
        if local in SECTION_PREDICATES:
            start_nodes.append((str(o), SECTION_PREDICATES[local]))

# Flood-fill from each start node (successors only)
for root, sec in start_nodes:
    if root in node_tag:            # already claimed by another section
        continue
    queue = deque([root])
    while queue:
        n = queue.popleft()
        if n in node_tag:           # visited via another root
            continue
        node_tag[n] = sec
        queue.extend(G.successors(n))

# --- 6. Tag everything else by namespace prefix ---------------------------
for n in G.nodes:
    if n in node_tag:               # already tagged by section
        continue
    if n.startswith("http"):
        try:
            pref = ns_mgr.compute_qname(rdflib.URIRef(n))[0]
        except Exception:
            pref = "misc"
    else:
        pref = "literal"
    node_tag[n] = pref

# --- 7. Build color palette ----------------------------------------------
all_tags = sorted(set(node_tag.values()))
cmap = cm.get_cmap("tab20", len(all_tags))
TAG2COLOR = {tag: to_hex(cmap(i)) for i, tag in enumerate(all_tags)}

# --- 8. Write node attributes ---------------------------------------------
for n in G.nodes:
    tag = node_tag[n]
    G.nodes[n]["group"] = tag       # human-readable
    G.nodes[n]["color"] = TAG2COLOR[tag]  # hex for Gephi partition

# --- 9. Export -------------------------------------------------------------
nx.write_graphml(G, OUT_FILE)
print(f"✔ GraphML with hybrid colors -> {OUT_FILE}")
# Out:
# C:\Users\Georgi\AppData\Local\Temp\ipykernel_6012\295889597.py:80: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap("tab20", len(all_tags))
# ✔ GraphML with hybrid colors -> ttl_graph_hybrid_colors.graphml
